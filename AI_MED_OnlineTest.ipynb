# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
import tensorflow_hub as hub
import os

# %%
#決定主要變數
img_size = 64
batch_size = 128
init_filter = 64
epoch = 50
cardinality = 0
features = '-original'

#DataAugmentation
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=20
    )

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

#載入資料集
train_set = train_datagen.flow_from_directory(
    'train',
    target_size=(img_size, img_size),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False   
)


valid_set = test_datagen.flow_from_directory(
    'valid',
    target_size=(img_size, img_size),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)

#不會加入訓練，僅作為模型表現之參考
test_set = test_datagen.flow_from_directory(
    'test',
    target_size=(img_size, img_size),
    color_mode='rgb',
    classes=None,
    class_mode='categorical',
    batch_size=batch_size,
    shuffle=True,
    seed=None,
    save_to_dir=None,
    save_prefix='',
    save_format='png',
    follow_links=False,
    subset=None,
    interpolation='nearest',
    keep_aspect_ratio=False
)
# Out:
# Found 9866 images belonging to 11 classes.
# Found 3430 images belonging to 11 classes.
# Found 3347 images belonging to 11 classes.

# %%
#觀察許多結構有類似表現，因此特別寫一個函數出來，避免後續程式碼過於冗長
def transform_layer(x, filters, kernel_size):
    out = layers.Conv2D(filters, kernel_size, padding='same')(x)
    out = layers.BatchNormalization()(out)
    out = layers.ReLU()(out)
    return out

#題目中左邊（cardinality=0，同時是後續實作Resnet50中的第二種bottleneck）與中間之residual block（cardinality!=0）
def Residual_Block_1_2(inputs, filters, cardinality):
    x = layers.Conv2D(filters,1)(inputs)
    fx = transform_layer(inputs, filters/4, 1)   
    if cardinality != 0:
        layers_split = list()
        for i in range(cardinality):
            splits = transform_layer(fx, filters/4, 3)
            layers_split.append(splits)
        layers_split = tf.keras.layers.concatenate(layers_split)
        fx = transform_layer(layers_split, filters, 3)
    else:
        fx = transform_layer(fx,filters, 3)
        
    fx = layers.Conv2D(filters, 1, padding='same')(fx)
    fx = layers.BatchNormalization()(fx)
    outputs = layers.Add()([x,fx])
    outputs = layers.ReLU()(outputs)
    return outputs
    
#題目中右邊之residual block
def Residual_Block_3(inputs, filters):
    x = layers.Conv2D(filters,1)(inputs)    
    fx = transform_layer(inputs, filters/4,1)
    fx1 = transform_layer(fx, filters/4,3)
    fx2 = transform_layer(fx, filters/4,3)
    fx3 = transform_layer(fx, filters/4,1)
    
    fx1 = tf.keras.layers.GlobalAveragePooling2D()(fx1)
    fx4 = tf.keras.layers.Multiply()([fx1,fx2])
    fx4 = transform_layer(fx4, filters,1)
    
    fx5 = tf.keras.layers.concatenate([fx3,fx4])
    fx5 = layers.Conv2D(filters, 3, padding='same')(fx5)
    fx5 = layers.BatchNormalization()(fx5)
    
    outputs = layers.Add()([x,fx4,fx5])
    outputs = layers.ReLU()(outputs)
    
    return outputs   

#後續實作Resnet50中的第一種bottleneck，且加入strides為變數
def BTNK_1(inputs, filters, strides):
    x = layers.Conv2D(int(4*filters/strides), 1, strides=strides)(inputs)
    fx = transform_layer(inputs, int(filters/strides), 1)   
    fx = transform_layer(fx, int(filters/strides), 3)       
    fx = layers.Conv2D(int(4*filters/strides), 1, padding='same',strides=strides)(fx)
    fx = layers.BatchNormalization()(fx)
    outputs = layers.Add()([x,fx])
    outputs = layers.ReLU()(outputs)
    return outputs

# %%
print(img_size,batch_size,init_filter,epoch,cardinality)
#Resnet50_stage_input
inputs = keras.Input(shape=(img_size, img_size, 3))

#Resnet50_stage_0
x = layers.Conv2D(init_filter,2,strides=2)(inputs)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = layers.MaxPool2D(pool_size=3, strides=2,padding='same')(x)

#Resnet50_stage_1
x = BTNK_1(x, init_filter, 1)
x = Residual_Block_1_2(x, 4*init_filter, cardinality)
x = Residual_Block_1_2(x, 4*init_filter, cardinality)

#Resnet50_stage_2
x = BTNK_1(x, init_filter, 2)
x = Residual_Block_1_2(x, 8*init_filter, cardinality)
x = Residual_Block_1_2(x, 8*init_filter, cardinality)
x = Residual_Block_1_2(x, 8*init_filter, cardinality)

#Resnet50_stage_3
x = BTNK_1(x, init_filter, 2)
x = Residual_Block_1_2(x, 16*init_filter, cardinality)
x = Residual_Block_1_2(x, 16*init_filter, cardinality)
x = Residual_Block_1_2(x, 16*init_filter, cardinality)
x = Residual_Block_1_2(x, 16*init_filter, cardinality)
x = Residual_Block_1_2(x, 16*init_filter, cardinality)

#Resnet50_stage_4
x = BTNK_1(x, init_filter, 2)
x = Residual_Block_1_2(x, 32*init_filter, cardinality)
x = Residual_Block_1_2(x, 32*init_filter, cardinality)

#Resnet50_stage_output
x = layers.AveragePooling2D()(x)
x = tf.keras.layers.Flatten()(x)
outputs = layers.Dense(11, activation='softmax')(x)
model = keras.Model(inputs=inputs,outputs=outputs)
model.summary()
# Out:
# 128 64 64 50 0
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_857 (Conv2D)            (None, 64, 64, 64)   832         ['input_14[0][0]']
#
#  batch_normalization_664 (Batch  (None, 64, 64, 64)  256         ['conv2d_857[0][0]']
#  Normalization)
#
#  re_lu_664 (ReLU)               (None, 64, 64, 64)   0           ['batch_normalization_664[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 32, 32, 64)  0           ['re_lu_664[0][0]']
#  )
#
#  conv2d_859 (Conv2D)            (None, 32, 32, 64)   4160        ['max_pooling2d_13[0][0]']
#
#  batch_normalization_665 (Batch  (None, 32, 32, 64)  256         ['conv2d_859[0][0]']
#  Normalization)
#
#  re_lu_665 (ReLU)               (None, 32, 32, 64)   0           ['batch_normalization_665[0][0]']
#
#  conv2d_860 (Conv2D)            (None, 32, 32, 64)   36928       ['re_lu_665[0][0]']
#
#  batch_normalization_666 (Batch  (None, 32, 32, 64)  256         ['conv2d_860[0][0]']
#  Normalization)
#
#  re_lu_666 (ReLU)               (None, 32, 32, 64)   0           ['batch_normalization_666[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 32, 32, 256)  16640       ['re_lu_666[0][0]']
#
#  conv2d_858 (Conv2D)            (None, 32, 32, 256)  16640       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_667 (Batch  (None, 32, 32, 256)  1024       ['conv2d_861[0][0]']
#  Normalization)
#
#  add_193 (Add)                  (None, 32, 32, 256)  0           ['conv2d_858[0][0]',
#                                                                   'batch_normalization_667[0][0]']
#
#  re_lu_667 (ReLU)               (None, 32, 32, 256)  0           ['add_193[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 32, 32, 64)   16448       ['re_lu_667[0][0]']
#
#  batch_normalization_668 (Batch  (None, 32, 32, 64)  256         ['conv2d_863[0][0]']
#  Normalization)
#
#  re_lu_668 (ReLU)               (None, 32, 32, 64)   0           ['batch_normalization_668[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 32, 32, 256)  147712      ['re_lu_668[0][0]']
#
#  batch_normalization_669 (Batch  (None, 32, 32, 256)  1024       ['conv2d_864[0][0]']
#  Normalization)
#
#  re_lu_669 (ReLU)               (None, 32, 32, 256)  0           ['batch_normalization_669[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 32, 32, 256)  65792       ['re_lu_669[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 32, 32, 256)  65792       ['re_lu_667[0][0]']
#
#  batch_normalization_670 (Batch  (None, 32, 32, 256)  1024       ['conv2d_865[0][0]']
#  Normalization)
#
#  add_194 (Add)                  (None, 32, 32, 256)  0           ['conv2d_862[0][0]',
#                                                                   'batch_normalization_670[0][0]']
#
#  re_lu_670 (ReLU)               (None, 32, 32, 256)  0           ['add_194[0][0]']
#
#  conv2d_867 (Conv2D)            (None, 32, 32, 64)   16448       ['re_lu_670[0][0]']
#
#  batch_normalization_671 (Batch  (None, 32, 32, 64)  256         ['conv2d_867[0][0]']
#  Normalization)
#
#  re_lu_671 (ReLU)               (None, 32, 32, 64)   0           ['batch_normalization_671[0][0]']
#
#  conv2d_868 (Conv2D)            (None, 32, 32, 256)  147712      ['re_lu_671[0][0]']
#
#  batch_normalization_672 (Batch  (None, 32, 32, 256)  1024       ['conv2d_868[0][0]']
#  Normalization)
#
#  re_lu_672 (ReLU)               (None, 32, 32, 256)  0           ['batch_normalization_672[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 32, 32, 256)  65792       ['re_lu_672[0][0]']
#
#  conv2d_866 (Conv2D)            (None, 32, 32, 256)  65792       ['re_lu_670[0][0]']
#
#  batch_normalization_673 (Batch  (None, 32, 32, 256)  1024       ['conv2d_869[0][0]']
#  Normalization)
#
#  add_195 (Add)                  (None, 32, 32, 256)  0           ['conv2d_866[0][0]',
#                                                                   'batch_normalization_673[0][0]']
#
#  re_lu_673 (ReLU)               (None, 32, 32, 256)  0           ['add_195[0][0]']
#
#  conv2d_871 (Conv2D)            (None, 32, 32, 32)   8224        ['re_lu_673[0][0]']
#
#  batch_normalization_674 (Batch  (None, 32, 32, 32)  128         ['conv2d_871[0][0]']
#  Normalization)
#
#  re_lu_674 (ReLU)               (None, 32, 32, 32)   0           ['batch_normalization_674[0][0]']
#
#  conv2d_872 (Conv2D)            (None, 32, 32, 32)   9248        ['re_lu_674[0][0]']
#
#  batch_normalization_675 (Batch  (None, 32, 32, 32)  128         ['conv2d_872[0][0]']
#  Normalization)
#
#  re_lu_675 (ReLU)               (None, 32, 32, 32)   0           ['batch_normalization_675[0][0]']
#
#  conv2d_873 (Conv2D)            (None, 16, 16, 128)  4224        ['re_lu_675[0][0]']
#
#  conv2d_870 (Conv2D)            (None, 16, 16, 128)  32896       ['re_lu_673[0][0]']
#
#  batch_normalization_676 (Batch  (None, 16, 16, 128)  512        ['conv2d_873[0][0]']
#  Normalization)
#
#  add_196 (Add)                  (None, 16, 16, 128)  0           ['conv2d_870[0][0]',
#                                                                   'batch_normalization_676[0][0]']
#
#  re_lu_676 (ReLU)               (None, 16, 16, 128)  0           ['add_196[0][0]']
#
#  conv2d_875 (Conv2D)            (None, 16, 16, 128)  16512       ['re_lu_676[0][0]']
#
#  batch_normalization_677 (Batch  (None, 16, 16, 128)  512        ['conv2d_875[0][0]']
#  Normalization)
#
#  re_lu_677 (ReLU)               (None, 16, 16, 128)  0           ['batch_normalization_677[0][0]']
#
#  conv2d_876 (Conv2D)            (None, 16, 16, 512)  590336      ['re_lu_677[0][0]']
#
#  batch_normalization_678 (Batch  (None, 16, 16, 512)  2048       ['conv2d_876[0][0]']
#  Normalization)
#
#  re_lu_678 (ReLU)               (None, 16, 16, 512)  0           ['batch_normalization_678[0][0]']
#
#  conv2d_877 (Conv2D)            (None, 16, 16, 512)  262656      ['re_lu_678[0][0]']
#
#  conv2d_874 (Conv2D)            (None, 16, 16, 512)  66048       ['re_lu_676[0][0]']
#
#  batch_normalization_679 (Batch  (None, 16, 16, 512)  2048       ['conv2d_877[0][0]']
#  Normalization)
#
#  add_197 (Add)                  (None, 16, 16, 512)  0           ['conv2d_874[0][0]',
#                                                                   'batch_normalization_679[0][0]']
#
#  re_lu_679 (ReLU)               (None, 16, 16, 512)  0           ['add_197[0][0]']
#
#  conv2d_879 (Conv2D)            (None, 16, 16, 128)  65664       ['re_lu_679[0][0]']
#
#  batch_normalization_680 (Batch  (None, 16, 16, 128)  512        ['conv2d_879[0][0]']
#  Normalization)
#
#  re_lu_680 (ReLU)               (None, 16, 16, 128)  0           ['batch_normalization_680[0][0]']
#
#  conv2d_880 (Conv2D)            (None, 16, 16, 512)  590336      ['re_lu_680[0][0]']
#
#  batch_normalization_681 (Batch  (None, 16, 16, 512)  2048       ['conv2d_880[0][0]']
#  Normalization)
#
#  re_lu_681 (ReLU)               (None, 16, 16, 512)  0           ['batch_normalization_681[0][0]']
#
#  conv2d_881 (Conv2D)            (None, 16, 16, 512)  262656      ['re_lu_681[0][0]']
#
#  conv2d_878 (Conv2D)            (None, 16, 16, 512)  262656      ['re_lu_679[0][0]']
#
#  batch_normalization_682 (Batch  (None, 16, 16, 512)  2048       ['conv2d_881[0][0]']
#  Normalization)
#
#  add_198 (Add)                  (None, 16, 16, 512)  0           ['conv2d_878[0][0]',
#                                                                   'batch_normalization_682[0][0]']
#
#  re_lu_682 (ReLU)               (None, 16, 16, 512)  0           ['add_198[0][0]']
#
#  conv2d_883 (Conv2D)            (None, 16, 16, 128)  65664       ['re_lu_682[0][0]']
#
#  batch_normalization_683 (Batch  (None, 16, 16, 128)  512        ['conv2d_883[0][0]']
#  Normalization)
#
#  re_lu_683 (ReLU)               (None, 16, 16, 128)  0           ['batch_normalization_683[0][0]']
#
#  conv2d_884 (Conv2D)            (None, 16, 16, 512)  590336      ['re_lu_683[0][0]']
#
#  batch_normalization_684 (Batch  (None, 16, 16, 512)  2048       ['conv2d_884[0][0]']
#  Normalization)
#
#  re_lu_684 (ReLU)               (None, 16, 16, 512)  0           ['batch_normalization_684[0][0]']
#
#  conv2d_885 (Conv2D)            (None, 16, 16, 512)  262656      ['re_lu_684[0][0]']
#
#  conv2d_882 (Conv2D)            (None, 16, 16, 512)  262656      ['re_lu_682[0][0]']
#
#  batch_normalization_685 (Batch  (None, 16, 16, 512)  2048       ['conv2d_885[0][0]']
#  Normalization)
#
#  add_199 (Add)                  (None, 16, 16, 512)  0           ['conv2d_882[0][0]',
#                                                                   'batch_normalization_685[0][0]']
#
#  re_lu_685 (ReLU)               (None, 16, 16, 512)  0           ['add_199[0][0]']
#
#  conv2d_887 (Conv2D)            (None, 16, 16, 32)   16416       ['re_lu_685[0][0]']
#
#  batch_normalization_686 (Batch  (None, 16, 16, 32)  128         ['conv2d_887[0][0]']
#  Normalization)
#
#  re_lu_686 (ReLU)               (None, 16, 16, 32)   0           ['batch_normalization_686[0][0]']
#
#  conv2d_888 (Conv2D)            (None, 16, 16, 32)   9248        ['re_lu_686[0][0]']
#
#  batch_normalization_687 (Batch  (None, 16, 16, 32)  128         ['conv2d_888[0][0]']
#  Normalization)
#
#  re_lu_687 (ReLU)               (None, 16, 16, 32)   0           ['batch_normalization_687[0][0]']
#
#  conv2d_889 (Conv2D)            (None, 8, 8, 128)    4224        ['re_lu_687[0][0]']
#
#  conv2d_886 (Conv2D)            (None, 8, 8, 128)    65664       ['re_lu_685[0][0]']
#
#  batch_normalization_688 (Batch  (None, 8, 8, 128)   512         ['conv2d_889[0][0]']
#  Normalization)
#
#  add_200 (Add)                  (None, 8, 8, 128)    0           ['conv2d_886[0][0]',
#                                                                   'batch_normalization_688[0][0]']
#
#  re_lu_688 (ReLU)               (None, 8, 8, 128)    0           ['add_200[0][0]']
#
#  conv2d_891 (Conv2D)            (None, 8, 8, 256)    33024       ['re_lu_688[0][0]']
#
#  batch_normalization_689 (Batch  (None, 8, 8, 256)   1024        ['conv2d_891[0][0]']
#  Normalization)
#
#  re_lu_689 (ReLU)               (None, 8, 8, 256)    0           ['batch_normalization_689[0][0]']
#
#  conv2d_892 (Conv2D)            (None, 8, 8, 1024)   2360320     ['re_lu_689[0][0]']
#
#  batch_normalization_690 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_892[0][0]']
#  Normalization)
#
#  re_lu_690 (ReLU)               (None, 8, 8, 1024)   0           ['batch_normalization_690[0][0]']
#
#  conv2d_893 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_690[0][0]']
#
#  conv2d_890 (Conv2D)            (None, 8, 8, 1024)   132096      ['re_lu_688[0][0]']
#
#  batch_normalization_691 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_893[0][0]']
#  Normalization)
#
#  add_201 (Add)                  (None, 8, 8, 1024)   0           ['conv2d_890[0][0]',
#                                                                   'batch_normalization_691[0][0]']
#
#  re_lu_691 (ReLU)               (None, 8, 8, 1024)   0           ['add_201[0][0]']
#
#  conv2d_895 (Conv2D)            (None, 8, 8, 256)    262400      ['re_lu_691[0][0]']
#
#  batch_normalization_692 (Batch  (None, 8, 8, 256)   1024        ['conv2d_895[0][0]']
#  Normalization)
#
#  re_lu_692 (ReLU)               (None, 8, 8, 256)    0           ['batch_normalization_692[0][0]']
#
#  conv2d_896 (Conv2D)            (None, 8, 8, 1024)   2360320     ['re_lu_692[0][0]']
#
#  batch_normalization_693 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_896[0][0]']
#  Normalization)
#
#  re_lu_693 (ReLU)               (None, 8, 8, 1024)   0           ['batch_normalization_693[0][0]']
#
#  conv2d_897 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_693[0][0]']
#
#  conv2d_894 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_691[0][0]']
#
#  batch_normalization_694 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_897[0][0]']
#  Normalization)
#
#  add_202 (Add)                  (None, 8, 8, 1024)   0           ['conv2d_894[0][0]',
#                                                                   'batch_normalization_694[0][0]']
#
#  re_lu_694 (ReLU)               (None, 8, 8, 1024)   0           ['add_202[0][0]']
#
#  conv2d_899 (Conv2D)            (None, 8, 8, 256)    262400      ['re_lu_694[0][0]']
#
#  batch_normalization_695 (Batch  (None, 8, 8, 256)   1024        ['conv2d_899[0][0]']
#  Normalization)
#
#  re_lu_695 (ReLU)               (None, 8, 8, 256)    0           ['batch_normalization_695[0][0]']
#
#  conv2d_900 (Conv2D)            (None, 8, 8, 1024)   2360320     ['re_lu_695[0][0]']
#
#  batch_normalization_696 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_900[0][0]']
#  Normalization)
#
#  re_lu_696 (ReLU)               (None, 8, 8, 1024)   0           ['batch_normalization_696[0][0]']
#
#  conv2d_901 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_696[0][0]']
#
#  conv2d_898 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_694[0][0]']
#
#  batch_normalization_697 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_901[0][0]']
#  Normalization)
#
#  add_203 (Add)                  (None, 8, 8, 1024)   0           ['conv2d_898[0][0]',
#                                                                   'batch_normalization_697[0][0]']
#
#  re_lu_697 (ReLU)               (None, 8, 8, 1024)   0           ['add_203[0][0]']
#
#  conv2d_903 (Conv2D)            (None, 8, 8, 256)    262400      ['re_lu_697[0][0]']
#
#  batch_normalization_698 (Batch  (None, 8, 8, 256)   1024        ['conv2d_903[0][0]']
#  Normalization)
#
#  re_lu_698 (ReLU)               (None, 8, 8, 256)    0           ['batch_normalization_698[0][0]']
#
#  conv2d_904 (Conv2D)            (None, 8, 8, 1024)   2360320     ['re_lu_698[0][0]']
#
#  batch_normalization_699 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_904[0][0]']
#  Normalization)
#
#  re_lu_699 (ReLU)               (None, 8, 8, 1024)   0           ['batch_normalization_699[0][0]']
#
#  conv2d_905 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_699[0][0]']
#
#  conv2d_902 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_697[0][0]']
#
#  batch_normalization_700 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_905[0][0]']
#  Normalization)
#
#  add_204 (Add)                  (None, 8, 8, 1024)   0           ['conv2d_902[0][0]',
#                                                                   'batch_normalization_700[0][0]']
#
#  re_lu_700 (ReLU)               (None, 8, 8, 1024)   0           ['add_204[0][0]']
#
#  conv2d_907 (Conv2D)            (None, 8, 8, 256)    262400      ['re_lu_700[0][0]']
#
#  batch_normalization_701 (Batch  (None, 8, 8, 256)   1024        ['conv2d_907[0][0]']
#  Normalization)
#
#  re_lu_701 (ReLU)               (None, 8, 8, 256)    0           ['batch_normalization_701[0][0]']
#
#  conv2d_908 (Conv2D)            (None, 8, 8, 1024)   2360320     ['re_lu_701[0][0]']
#
#  batch_normalization_702 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_908[0][0]']
#  Normalization)
#
#  re_lu_702 (ReLU)               (None, 8, 8, 1024)   0           ['batch_normalization_702[0][0]']
#
#  conv2d_909 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_702[0][0]']
#
#  conv2d_906 (Conv2D)            (None, 8, 8, 1024)   1049600     ['re_lu_700[0][0]']
#
#  batch_normalization_703 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_909[0][0]']
#  Normalization)
#
#  add_205 (Add)                  (None, 8, 8, 1024)   0           ['conv2d_906[0][0]',
#                                                                   'batch_normalization_703[0][0]']
#
#  re_lu_703 (ReLU)               (None, 8, 8, 1024)   0           ['add_205[0][0]']
#
#  conv2d_911 (Conv2D)            (None, 8, 8, 32)     32800       ['re_lu_703[0][0]']
#
#  batch_normalization_704 (Batch  (None, 8, 8, 32)    128         ['conv2d_911[0][0]']
#  Normalization)
#
#  re_lu_704 (ReLU)               (None, 8, 8, 32)     0           ['batch_normalization_704[0][0]']
#
#  conv2d_912 (Conv2D)            (None, 8, 8, 32)     9248        ['re_lu_704[0][0]']
#
#  batch_normalization_705 (Batch  (None, 8, 8, 32)    128         ['conv2d_912[0][0]']
#  Normalization)
#
#  re_lu_705 (ReLU)               (None, 8, 8, 32)     0           ['batch_normalization_705[0][0]']
#
#  conv2d_913 (Conv2D)            (None, 4, 4, 128)    4224        ['re_lu_705[0][0]']
#
#  conv2d_910 (Conv2D)            (None, 4, 4, 128)    131200      ['re_lu_703[0][0]']
#
#  batch_normalization_706 (Batch  (None, 4, 4, 128)   512         ['conv2d_913[0][0]']
#  Normalization)
#
#  add_206 (Add)                  (None, 4, 4, 128)    0           ['conv2d_910[0][0]',
#                                                                   'batch_normalization_706[0][0]']
#
#  re_lu_706 (ReLU)               (None, 4, 4, 128)    0           ['add_206[0][0]']
#
#  conv2d_915 (Conv2D)            (None, 4, 4, 512)    66048       ['re_lu_706[0][0]']
#
#  batch_normalization_707 (Batch  (None, 4, 4, 512)   2048        ['conv2d_915[0][0]']
#  Normalization)
#
#  re_lu_707 (ReLU)               (None, 4, 4, 512)    0           ['batch_normalization_707[0][0]']
#
#  conv2d_916 (Conv2D)            (None, 4, 4, 2048)   9439232     ['re_lu_707[0][0]']
#
#  batch_normalization_708 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_916[0][0]']
#  Normalization)
#
#  re_lu_708 (ReLU)               (None, 4, 4, 2048)   0           ['batch_normalization_708[0][0]']
#
#  conv2d_917 (Conv2D)            (None, 4, 4, 2048)   4196352     ['re_lu_708[0][0]']
#
#  conv2d_914 (Conv2D)            (None, 4, 4, 2048)   264192      ['re_lu_706[0][0]']
#
#  batch_normalization_709 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_917[0][0]']
#  Normalization)
#
#  add_207 (Add)                  (None, 4, 4, 2048)   0           ['conv2d_914[0][0]',
#                                                                   'batch_normalization_709[0][0]']
#
#  re_lu_709 (ReLU)               (None, 4, 4, 2048)   0           ['add_207[0][0]']
#
#  conv2d_919 (Conv2D)            (None, 4, 4, 512)    1049088     ['re_lu_709[0][0]']
#
#  batch_normalization_710 (Batch  (None, 4, 4, 512)   2048        ['conv2d_919[0][0]']
#  Normalization)
#
#  re_lu_710 (ReLU)               (None, 4, 4, 512)    0           ['batch_normalization_710[0][0]']
#
#  conv2d_920 (Conv2D)            (None, 4, 4, 2048)   9439232     ['re_lu_710[0][0]']
#  batch_normalization_711 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_920[0][0]']
#  Normalization)
#
#  re_lu_711 (ReLU)               (None, 4, 4, 2048)   0           ['batch_normalization_711[0][0]']
#
#  conv2d_921 (Conv2D)            (None, 4, 4, 2048)   4196352     ['re_lu_711[0][0]']
#
#  conv2d_918 (Conv2D)            (None, 4, 4, 2048)   4196352     ['re_lu_709[0][0]']
#
#  batch_normalization_712 (Batch  (None, 4, 4, 2048)  8192        ['conv2d_921[0][0]']
#  Normalization)
#
#  add_208 (Add)                  (None, 4, 4, 2048)   0           ['conv2d_918[0][0]',
#                                                                   'batch_normalization_712[0][0]']
#
#  re_lu_712 (ReLU)               (None, 4, 4, 2048)   0           ['add_208[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 2, 2, 2048)  0           ['re_lu_712[0][0]']
#  ooling2D)
#
#  flatten_12 (Flatten)           (None, 8192)         0           ['average_pooling2d_12[0][0]']
#
#  dense_12 (Dense)               (None, 11)           90123       ['flatten_12[0][0]']
#
# ==================================================================================================
# Total params: 59,797,643
# Trainable params: 59,744,907
# Non-trainable params: 52,736
# __________________________________________________________________________________________________

# %%
img_size = 299
batch_size = 64
init_filter = 0
epoch = 50
cardinality = 0
features = '-transfer'

module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/2"

model = tf.keras.Sequential([
    # hub.KerasLayer載入的模型為Keras Layer
    hub.KerasLayer(module_url,
                   input_shape=(299, 299, 3),  # 模型輸入大小
                   output_shape=(2048,),   # 模型輸出大小
                   trainable=False),  # 將模型訓練權重設定為False(凍結)
    # 最後接上兩層全連接層
    layers.Dense(128, activation='relu'), 
    layers.Dense(11, activation='relu')
])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_3 (KerasLayer)  (None, 2048)              21802784
#
#  dense_19 (Dense)            (None, 128)               262272
#
#  dense_20 (Dense)            (None, 11)                1419
#
# =================================================================
# Total params: 22,066,475
# Trainable params: 263,691
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# %load_ext tensorboard
# %tensorboard --logdir online_test-logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 97103), started 11:10:05 ago. (Use '!kill 97103' to kill it.)
#       <iframe id="tensorboard-frame-54294dab2c7a0b0c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-54294dab2c7a0b0c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
run_name = 'img_size-'+str(img_size)+'-batch_size-'+str(batch_size)+'-init_filter-'+str(init_filter)+'-epoch-'+str(epoch)+features
model_dir = 'online_test/models' 
os.makedirs(model_dir,exist_ok=True) 
print(img_size)

# 儲存訓練記錄檔
logfiles = 'online_test-logs/{}'.format(run_name)
model_cbk = keras.callbacks.TensorBoard(log_dir=logfiles, 
                                        histogram_freq=1)
# 儲存最好的網路模型權重
modelfiles = model_dir + '/{}-best-model.online_test'.format(run_name)
model_mckp = keras.callbacks.ModelCheckpoint(modelfiles, 
                                             monitor='val_categorical_accuracy', 
                                             save_best_only=True, 
                                             mode='max')

# 設定訓練使用的優化器、損失函數和指標函數
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=[keras.metrics.CategoricalAccuracy()])

# 訓練網路模型
model.fit(train_set,
          epochs=epoch, 
          validation_data=valid_set,
          callbacks=[model_cbk, model_mckp])
# Out:
# 299
# "'model.fit(train_set,\n          epochs=epoch, \n          validation_data=valid_set,\n          callbacks=[model_cbk, model_mckp])"

# %%
#評估網路模型效果
model.load_weights(modelfiles)
loss, acc = model.evaluate(test_set)
# Out:
# 2022-09-05 07:43:05.013356: W tensorflow/core/util/tensor_slice_reader.cc:96] Could not open online_test/models/img_size-128-batch_size-64-init_filter-64-epoch-50-transfer-best-model.online_test: FAILED_PRECONDITION: online_test/models/img_size-128-batch_size-64-init_filter-64-epoch-50-transfer-best-model.online_test; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 53/53 [==============================] - 56s 1s/step - loss: 2.7644 - categorical_accuracy: 0.5793
